# %% [markdown]
# # Deep Learning Model Example

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(learning_rate=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 1s 3ms/step - loss: 0.6817 - accuracy: 0.6820
# Epoch 2/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6077 - accuracy: 0.7820
# Epoch 3/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.8330
# Epoch 4/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.8550
# Epoch 5/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3929 - accuracy: 0.8690
# Epoch 6/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8760
# Epoch 7/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3359 - accuracy: 0.8750
# Epoch 8/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2895 - accuracy: 0.8940
# Epoch 9/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2246 - accuracy: 0.9220
# Epoch 10/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9890
# Epoch 11/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9990
# Epoch 12/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 1.0000
# Epoch 13/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 1.0000
# Epoch 14/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 1.0000
# Epoch 15/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 16/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 17/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 18/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 1.0000
# Epoch 19/20
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 20/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)
# Out:
# 319/319 [==============================] - 0s 1ms/step

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
